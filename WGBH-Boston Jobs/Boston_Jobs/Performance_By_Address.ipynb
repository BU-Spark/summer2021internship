# %%
import pandas as pd
from geolocation.main import GoogleMaps 
from geolocation.distance_matrix.client import DistanceMatrixApiClient
import requests
from urllib.parse import urlencode

# %%
df = pd.read_csv('Copy_of_wgbh.csv')

df.head()
# Out:
#   Agency                            ProjectName  \
# 0    COB             7042 JAMAICA PLAIN LIBRARY
# 1    COB  7123 ADAMS BRANCH LIBRARY RENOVATIONS
# 2    COB        7098 BPL RARE BOOKS RENOVATIONS
# 3    COB        7098 BPL RARE BOOKS RENOVATIONS
# 4    COB    7101 NEW EAST BOSTON POLICE STATION
#
#                         ProjectAddress_1               Developer  \
# 0                     12 SEDGWICK STREET    CITY OF BOSTON / PFD
# 1  690 ADAMS STREET DORCHESTER, MA 02122  CITY OF BOSTON   / PFD
# 2                     700 BOYLSON STREET  CITY OF BOSTON   / PFD
# 3                     700 BOYLSON STREET  CITY OF BOSTON   / PFD
# 4  338 EAST EAGLE STREET EAST BOSTON, MA  CITY OF BOSTON   / PFD
#
#           GeneralContractor              SubContractor SubContractorAddress_1  \
# 0   COLANTONIO INCORPORATED       KAPILOFF'S GLASS INC      47 NEW ASHFORD RD
# 1     J & J CONTRACTORS INC  NORTH EAST ENERGY CONTROL        50 GETCHELL WAY
# ...

# %%
def extract_town(address):
    api_key = ''
    data_type = 'json'
    endpoint = f'https://maps.googleapis.com/maps/api/geocode/{data_type}'
    params = {'address' : address, 'key' : api_key}
    url_params = urlencode(params)
    url = f'{endpoint}?{url_params}'
    r = requests.get(url)
    if r.status_code not in range(200, 299):
        return {}
    return r.json()['results']

# %%
addresses = df['SubContractorAddress_1']

zip_codes = pd.DataFrame(columns = ['ZIP_CODE'])

for i in range(len(addresses)):
    if len(extract_town(addresses.iloc[i])) == 0:
        zip_codes.loc[i] = None
    else:
        try:
            zip_codes.loc[i] = extract_town(addresses.iloc[i])[0]['address_components'][7]['long_name']
        except IndexError as e:
            zip_codes.loc[i] = None
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...
